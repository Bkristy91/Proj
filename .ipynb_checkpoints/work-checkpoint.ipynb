# %%
import numpy as np
import pandas as pd
import random

import matplotlib
import matplotlib.image as img
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, cross_val_score

# 3. Модели
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import KFold, GridSearchCV

# 4. Метрики качества
from sklearn.metrics import mean_squared_error as mse, r2_score as r2

# 5. Для визуализации внешних картинок в ноутбуке
from IPython.display import Image

# %%
# %matplotlib inline

# %%
matplotlib.rcParams.update({'font.size': 12})  # размер шрифта на графиках

# %% [markdown]
# Загрузка данных

# %%
DATASET_PATH_1 = './priem.csv'
DATASET_PATH_2 = './uvolnenie.csv'

df_priem = pd.read_csv(DATASET_PATH_1, encoding = "cp1251", sep=';')
df_priem = df_priem.drop(columns=['Unnamed: 2', 'Причина увольнения по результатам собеседования',
                     'Описание причины увольнения', 'Дата следующего приема', 'Количество дней между увольнением и приемом'])
df_uvolnenie = pd.read_csv(DATASET_PATH_2, encoding = "cp1251", sep=';')
df_uvolnenie = df_uvolnenie.drop(columns=['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6'])

# %%
df_priem.head(3)
# Out:
#    № в группе                Физическое лицо Дата приема Дата увольнения  \
# 0           1     Бадодина Галина Викторовна  12.04.2010             NaN
# 1           2  Ананьев Евгений Александрович  20.04.2010             NaN
# 2           3   Никитченко Василий Матвеевич  01.07.2010             NaN
#
#                                     Подразделение  \
# 0  Центральный офис (Административное управление)
# 1                                 ПРС_Владоптснаб
# 2               07.03. Судоремонтное производство
#
#                      Подразделение первого уровня  \
# 0  Центральный офис (Административное управление)
# 1                                 ПРС_Владоптснаб
# 2       07. Управление судоремонта и судостроения
#
#                              Должность Причина увольнения
# 0             Помощник управляющего ГК                NaN
# 1  Ведущий специалист отдела логистики                NaN
# 2                      Сменный механик                NaN

# %%
df_priem.shape
# Out:
# (35485, 8)

# %%
df_uvolnenie.head(3)
# Out:
#    № в группе            Физическое лицо Дата приема Дата увольнения  \
# 0           6            Чайковский С.В.  16.03.2009      01.01.2010
# 1           7  Штин Сергей Александрович  24.03.2009      01.01.2010
# 2          17  Вергун Александр Иванович  26.05.2009      13.01.2010
#
#      Подразделение      Подразделение первого уровня  \
# 0  НМ_Кострома СТР  03. Управление промысла (добычи)
# 1  НМ_Кострома СТР  03. Управление промысла (добычи)
# 2   НМ_Седанка СТР  03. Управление промысла (добычи)
#
#                                Должность  \
# 0  Помощник капитана по радиоэлектронике
# 1               Третий помощник капитана
# 2                        Старший механик
#
#                             Причина увольнения
# 0  (НЕ ИСПОЛЬЗОВАТЬ) По собственному желанию А
# 1  (НЕ ИСПОЛЬЗОВАТЬ) По собственному желанию А
# 2  (НЕ ИСПОЛЬЗОВАТЬ) По собственному желанию А

# %%
df_uvolnenie.shape
# Out:
# (6609, 8)

# %%
df = df_priem
df.shape
# Out:
# (35485, 8)

# %%
df = df.append(df_uvolnenie)
df.shape
# Out:
# (42094, 8)

# %%
df.head(3)
# Out:
#    № в группе                Физическое лицо Дата приема Дата увольнения  \
# 0           1     Бадодина Галина Викторовна  12.04.2010             NaN
# 1           2  Ананьев Евгений Александрович  20.04.2010             NaN
# 2           3   Никитченко Василий Матвеевич  01.07.2010             NaN
#
#                                     Подразделение  \
# 0  Центральный офис (Административное управление)
# 1                                 ПРС_Владоптснаб
# 2               07.03. Судоремонтное производство
#
#                      Подразделение первого уровня  \
# 0  Центральный офис (Административное управление)
# 1                                 ПРС_Владоптснаб
# 2       07. Управление судоремонта и судостроения
#
#                              Должность Причина увольнения
# 0             Помощник управляющего ГК                NaN
# 1  Ведущий специалист отдела логистики                NaN
# 2                      Сменный механик                NaN

# %% [markdown]
# Перекодируем переменные в дату

# %%
df['Дата приема'] = pd.to_datetime(df['Дата приема'])
df['Дата увольнения'] = pd.to_datetime(df['Дата увольнения'])

# %%
df[df['Физическое лицо'].str.match('Храмец')]
# Out:
#        № в группе             Физическое лицо Дата приема Дата увольнения  \
# 19953       19954  Храмец Андрей Владимирович  2016-07-12      2016-12-19
# 23069       23070  Храмец Андрей Владимирович  2017-07-25      2018-01-31
# 25268       25269  Храмец Андрей Владимирович  2018-07-17      2018-03-10
# 26634       26635  Храмец Андрей Владимирович  2019-08-02      2019-05-03
# 4373        19910  Храмец Андрей Владимирович  2017-07-25      2018-01-31
# 4772        22108  Храмец Андрей Владимирович  2018-07-17      2018-03-10
# 5000        23479  Храмец Андрей Владимирович  2019-08-02      2019-05-03
#
#                                      Подразделение  \
# 19953  02.1.1.2. Консервное производство бригада 2
# 23069                              ТРФ_Симфония ТР
# 25268                              ТРФ_Симфония ТР
# 26634                             НМ_Калиновск СТР
# 4373                               ТРФ_Симфония ТР
# 4772                               ТРФ_Симфония ТР
# 5000                              НМ_Калиновск СТР
#
#                       Подразделение первого уровня        Должность  \
# 19953                 02. Управление производством  Обработчик рыбы
# 23069  05. Управление логистики и проектного офиса  Матрос 1 класса
# 25268  05. Управление логистики и проектного офиса  Матрос 1 класса
# 26634             03. Управление промысла (добычи)  Матрос 1 класса
# 4373   05. Управление логистики и проектного офиса  Матрос 1 класса
# 4772   05. Управление логистики и проектного офиса  Матрос 1 класса
# 5000              03. Управление промысла (добычи)  Матрос 1 класса
#
#                                    Причина увольнения
# 19953   По состоянию здоровья (есть заключения врача)
# 23069  Истечение срока трудового договора, п2 ч1 ст77
# 25268                         Личные/семейные причины
# 26634                        Не выдержал темпа работы
# 4373   Истечение срока трудового договора, п2 ч1 ст77
# 4772                          Личные/семейные причины
# 5000                         Не выдержал темпа работы

# %% [markdown]
# Посчитаем количество дней между Датой увольнения и Датой следующего приема

# %%
df = df.sort_values(['Физическое лицо', 'Дата приема'])
df['Дни между ПиУ'] = ''
df['Дни между ПиУ'] = (df['Дата приема'] - df['Дата увольнения'].shift(1)).dt.days

#df.loc[df['Физическое лицо'] == df['Физическое лицо'].shift(1)]
df.loc[df['Физическое лицо'] != df['Физическое лицо'].shift(1), 'Дни между ПиУ'] = 0

# %%
df[df['Физическое лицо'].str.match('Храмец')]
# Out:
#        № в группе             Физическое лицо Дата приема Дата увольнения  \
# 19953       19954  Храмец Андрей Владимирович  2016-07-12      2016-12-19
# 23069       23070  Храмец Андрей Владимирович  2017-07-25      2018-01-31
# 4373        19910  Храмец Андрей Владимирович  2017-07-25      2018-01-31
# 25268       25269  Храмец Андрей Владимирович  2018-07-17      2018-03-10
# 4772        22108  Храмец Андрей Владимирович  2018-07-17      2018-03-10
# 26634       26635  Храмец Андрей Владимирович  2019-08-02      2019-05-03
# 5000        23479  Храмец Андрей Владимирович  2019-08-02      2019-05-03
#
#                                      Подразделение  \
# 19953  02.1.1.2. Консервное производство бригада 2
# 23069                              ТРФ_Симфония ТР
# 4373                               ТРФ_Симфония ТР
# 25268                              ТРФ_Симфония ТР
# 4772                               ТРФ_Симфония ТР
# 26634                             НМ_Калиновск СТР
# 5000                              НМ_Калиновск СТР
#
#                       Подразделение первого уровня        Должность  \
# 19953                 02. Управление производством  Обработчик рыбы
# 23069  05. Управление логистики и проектного офиса  Матрос 1 класса
# 4373   05. Управление логистики и проектного офиса  Матрос 1 класса
# 25268  05. Управление логистики и проектного офиса  Матрос 1 класса
# 4772   05. Управление логистики и проектного офиса  Матрос 1 класса
# 26634             03. Управление промысла (добычи)  Матрос 1 класса
# 5000              03. Управление промысла (добычи)  Матрос 1 класса
#
#                                    Причина увольнения  Дни между ПиУ
# 19953   По состоянию здоровья (есть заключения врача)            0.0
# 23069  Истечение срока трудового договора, п2 ч1 ст77          218.0
# 4373   Истечение срока трудового договора, п2 ч1 ст77         -190.0
# 25268                         Личные/семейные причины          167.0
# 4772                          Личные/семейные причины          129.0
# 26634                        Не выдержал темпа работы          510.0
# 5000                         Не выдержал темпа работы           91.0

# %% [markdown]
# Создаем таблицу, которая будет содержать уникальные данные по каждой персоне

# %%
df_target = df.drop_duplicates('Физическое лицо')
df_target = df_target.drop(columns=['Подразделение первого уровня', 'Дата приема', 'Дата увольнения', '№ в группе', 'Дни между ПиУ'])
df_target.head(3)
# Out:
#                             Физическое лицо  \
# 12706       !Дубль! Крюков Павел Валерьевич
# 11255  (УВОЛ) Бережная Надежда Владимировна
# 1043              Ёкубов Содик Шукруллаевич
#
#                                            Подразделение  \
# 12706                               ЮМРФ_Залив Восток ПЗ
# 11255               07.06. ЛРСЗ Служба главного инженера
# 1043   05.09.2. ОПЛ "Красный Вымпел" - Складская логи...
#
#                                   Должность  \
# 12706                       Матрос 1 класса
# 11255  Инженер по промышленной безопасности
# 1043                           Разнорабочий
#
#                                   Причина увольнения
# 12706                        Личные/семейные причины
# 11255  По состоянию здоровья (есть заключения врача)
# 1043                                             NaN

# %% [markdown]
# Найдем дату первого приема на работу, дату послженего приема на работу, дату полседнего увольнения и медиану дней между увольнениями и приемом на работу

# %%
df_target = df_target.merge(df.groupby('Физическое лицо')['Дата приема'].agg(['min']), left_on='Физическое лицо', right_on=df.groupby('Физическое лицо')['Дата приема'].agg(['min']).index)
df_target = df_target.merge(df.groupby('Физическое лицо')['Дата приема'].agg(['max']), left_on='Физическое лицо', right_on=df.groupby('Физическое лицо')['Дата приема'].agg(['max']).index)
df_target = df_target.merge(df.groupby('Физическое лицо')['Дата увольнения'].agg(['max']), left_on='Физическое лицо', right_on=df.groupby('Физическое лицо')['Дата увольнения'].agg(['max']).index)
df_target = df_target.merge(df.groupby('Физическое лицо')['Дни между ПиУ'].agg(['median']), left_on='Физическое лицо', right_on=df.groupby('Физическое лицо')['Дни между ПиУ'].agg(['median']).index)

# %% [markdown]
# Посчитаем количество дней между последним увольнением и приемом на работу

# %%
df_target['Кол-во дней между последним увольнением и приемом на работу'] = 0 
df_target['Кол-во дней между последним увольнением и приемом на работу'] = df_target['max_x'] - df_target['max_y']

# %% [markdown]
# Переименуем все столбцы, для удобства работы

# %%
df_target = df_target.rename(columns={'min': 'Первая адата приема', 'max_x': 'Последняя дата приема', 'max_y': 'Последняя дата увольнения', 'median': 'Среднее время между приемами на работу'})

# %% [markdown]
# Найдем количество рейсов, выполненных персоной

# %%
df['Физическое лицо'].value_counts().sort_index().values
df_target = df_target.sort_values('Физическое лицо')
df_target['Кол-во рейсов'] = df['Физическое лицо'].value_counts().sort_index().values

# %% [markdown]
# Посмотрим результат

# %%
df_target[df_target['Физическое лицо'].str.match('Храмец')]
# Out:
#                   Физическое лицо  \
# 20015  Храмец Андрей Владимирович
#
#                                      Подразделение        Должность  \
# 20015  02.1.1.2. Консервное производство бригада 2  Обработчик рыбы
#
#                                   Причина увольнения Первая адата приема  \
# 20015  По состоянию здоровья (есть заключения врача)          2016-07-12
#
#       Последняя дата приема Последняя дата увольнения  \
# 20015            2019-08-02                2019-05-03
#
#        Среднее время между приемами на работу  \
# 20015                                   129.0
#
#       Кол-во дней между последним увольнением и приемом на работу  \
# 20015                                            91 days
#
#        Кол-во рейсов
# 20015              7

# %%
df[df['Физическое лицо'].str.match('Храмец')]
# Out:
#        № в группе             Физическое лицо Дата приема Дата увольнения  \
# 19953       19954  Храмец Андрей Владимирович  2016-07-12      2016-12-19
# 23069       23070  Храмец Андрей Владимирович  2017-07-25      2018-01-31
# 4373        19910  Храмец Андрей Владимирович  2017-07-25      2018-01-31
# 25268       25269  Храмец Андрей Владимирович  2018-07-17      2018-03-10
# 4772        22108  Храмец Андрей Владимирович  2018-07-17      2018-03-10
# 26634       26635  Храмец Андрей Владимирович  2019-08-02      2019-05-03
# 5000        23479  Храмец Андрей Владимирович  2019-08-02      2019-05-03
#
#                                      Подразделение  \
# 19953  02.1.1.2. Консервное производство бригада 2
# 23069                              ТРФ_Симфония ТР
# 4373                               ТРФ_Симфония ТР
# 25268                              ТРФ_Симфония ТР
# 4772                               ТРФ_Симфония ТР
# 26634                             НМ_Калиновск СТР
# 5000                              НМ_Калиновск СТР
#
#                       Подразделение первого уровня        Должность  \
# 19953                 02. Управление производством  Обработчик рыбы
# 23069  05. Управление логистики и проектного офиса  Матрос 1 класса
# 4373   05. Управление логистики и проектного офиса  Матрос 1 класса
# 25268  05. Управление логистики и проектного офиса  Матрос 1 класса
# 4772   05. Управление логистики и проектного офиса  Матрос 1 класса
# 26634             03. Управление промысла (добычи)  Матрос 1 класса
# 5000              03. Управление промысла (добычи)  Матрос 1 класса
#
#                                    Причина увольнения  Дни между ПиУ
# 19953   По состоянию здоровья (есть заключения врача)            0.0
# 23069  Истечение срока трудового договора, п2 ч1 ст77          218.0
# 4373   Истечение срока трудового договора, п2 ч1 ст77         -190.0
# 25268                         Личные/семейные причины          167.0
# 4772                          Личные/семейные причины          129.0
# 26634                        Не выдержал темпа работы          510.0
# 5000                         Не выдержал темпа работы           91.0
